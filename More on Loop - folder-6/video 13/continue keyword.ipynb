# %%
# multiple of 7 not printed
n=int(input())
for i in range(1,n+1,1):
    if i%7==0:
        continue
    print(i)
# Out:
# 7
# 1
# 2
# 3
# 4
# 5
# 6

# %%
n=int(input())
for i in range(1,n+1,1):
    print(i)
    print("next code")
    if i%7==0:
        continue
    print(i)
# Out:
# 30
# 1
# next code
# 1
# 2
# next code
# 2
# 3
# next code
# 3
# 4
# next code
# 4
# 5
# next code
# 5
# 6
# next code
# 6
# 7
# next code
# 8
# next code
# 8
# 9
# next code
# 9
# 10
# next code
# 10
# 11
# next code
# 11
# 12
# next code
# 12
# 13
# next code
# 13
# 14
# next code
# 15
# next code
# 15
# 16
# next code
# 16
# 17
# next code
# 17
# 18
# next code
# 18
# 19
# next code
# 19
# 20
# next code
# 20
# 21
# next code
# 22
# next code
# 22
# 23
# next code
# 23
# 24
# next code
# 24
# 25
# next code
# 25
# 26
# next code
# 26
# 27
# next code
# 27
# 28
# next code
# 29
# next code
# 29
# 30
# next code
# 30

# %%
# print excpet mulp of 7 number
n = int(input())
i=2
while i<=n:
    if i%7==0:
        i+=2
        continue
    print(i)
    i+=2
# Out:
# 100
# 2
# 4
# 6
# 8
# 10
# 12
# 16
# 18
# 20
# 22
# 24
# 26
# 30
# 32
# 34
# 36
# 38
# 40
# 44
# 46
# 48
# 50
# 52
# 54
# 58
# 60
# 62
# 64
# 66
# 68
# 72
# 74
# 76
# 78
# 80
# 82
# 86
# 88
# 90
# 92
# 94
# 96
# 100
